# %%
# Databricks notebook source
# 1. Crear Esquemas por Capa (Medallion)
spark.sql("CREATE SCHEMA IF NOT EXISTS catalogo_electrocasa.bronze")
spark.sql("CREATE SCHEMA IF NOT EXISTS catalogo_electrocasa.silver")
spark.sql("CREATE SCHEMA IF NOT EXISTS catalogo_electrocasa.gold")

# 2. Confirmación de Volumen de Landing
print("Entorno aprovisionado correctamente con esquemas: bronze, silver, gold.")
